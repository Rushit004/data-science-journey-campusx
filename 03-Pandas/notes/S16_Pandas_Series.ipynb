# %% [markdown]
# ### What is Pandas
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Series from lists

# %%
country = ['India','Pakistan','USA','Nepal']
pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# dtype: object

# %%
# Integer
runs = [10,50,89,100,0]
pd.Series(runs)
# Out:
# 0     10
# 1     50
# 2     89
# 3    100
# 4      0
# dtype: int64

# %%
# custom names
marks = [67,89,78,45,100]
subject = ['OOP','CA','JP','DBMS','DC']
marks = pd.Series(marks,index = subject,name = 'Marks of Student')
marks
# Out:
# OOP      67
# CA       89
# JP       78
# DBMS     45
# DC      100
# Name: Marks of Student, dtype: int64

# %%
# Dictionary
marks_dict = {
    'OOP' : 67,
    'CA' :89,
    'JP':100,
    'OB':80
}
marks_series = pd.Series(marks_dict,name='RT marks')
marks_series
# Out:
# OOP     67
# CA      89
# JP     100
# OB      80
# Name: RT marks, dtype: int64

# %% [markdown]
# ### Series Attributes

# %%
# size
marks
# Out:
# OOP      67
# CA       89
# JP       78
# DBMS     45
# DC      100
# Name: Marks of Student, dtype: int64

# %%
marks.size
# Out:
# 5

# %%
# dtype
marks.dtype
# Out:
# dtype('int64')

# %%
# name
marks.name
# Out:
# 'Marks of Student'

# %%
# is_unique
marks.is_unique
# Out:
# True

# %%
# index
marks.index
# Out:
# Index(['OOP', 'CA', 'JP', 'DBMS', 'DC'], dtype='object')

# %%
runs.index
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
# values
m = marks.values
print(m)
print(type(m))
# Out:
# [ 67  89  78  45 100]
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Series using read_csv

# %%
d = pd.read_csv('Datasets/subs.csv')
d
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
print(type(d))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
subs = pd.read_csv('Datasets/subs.csv')
subs = subs.squeeze()
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
vk = pd.read_csv('Datasets/kohli_ipl.csv',index_col='match_no')
vk = vk.squeeze()
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('Datasets/bollywood.csv',index_col='movie')
movies = movies.squeeze()
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series Methods

# %%
# Heads
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
# tail
vk.tail(10)
# Out:
# match_no
# 206     0
# 207     0
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# sample
movies.sample(5)
# Out:
# movie
# Dil Dhadakne Do            Anil Kapoor
# Rustom (film)            Ileana D'Cruz
# Fashion (2008 film)    Priyanka Chopra
# Toh Baat Pakki!                   Tabu
# Mukhbiir                Sammir Dattani
# Name: lead, dtype: object

# %%
# value_counts ->movies
movies.value_counts()
# Out:
# lead
# Akshay Kumar          48
# Amitabh Bachchan      45
# Ajay Devgn            38
# Salman Khan           31
# Sanjay Dutt           26
#                       ..
# Talha Arshad Reshi     1
# Garima Agarwal         1
# Rasika Agashe          1
# Zaheer Iqbal           1
# Deepika Amin           1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values (method chaining)
vk.sort_values(ascending =False).head(1).values[0]
# if want perment changes(inplace)
# Out:
# np.int64(113)

# %%
# sort_index(inplace parameter if want permenent change)
movies.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series Maths Methods

# %%
# count(counts only not null values )
vk.count()
# Out:
# np.int64(215)

# %%
# sum
subs.sum()
# Out:
# np.int64(49510)

# %%
# product
subs.product()
# Out:
# np.int64(0)

# %%
# mean
subs.mean()
# Out:
# np.float64(135.64383561643837)

# %%
# median
vk.median()
# Out:
# np.float64(24.0)

# %%
# mode
movies.mode()
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: object

# %%
# standerd daviation
subs.std()
# Out:
# np.float64(62.6750230372527)

# %%
# varience
subs.var()
# Out:
# np.float64(3928.1585127201565)

# %%
# max
subs.max()
# Out:
# np.int64(396)

# %%
# min
subs.min()
# Out:
# np.int64(33)

# %%
# describe
vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# ### Series Indexing

# %%
x = pd.Series([12,13,14,35,46,57,58,79,9])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
x[0]
# Out:
# np.int64(12)

# %%
x[0:5]
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# dtype: int64

# %%
# negative indexing not allowed
# x[-2]

# %%
movies[0]

movies['Uri: The Surgical Strike']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18232\3409363160.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movies[0]
# 'Vicky Kaushal'

# %%
movies[-1]
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18232\2731571422.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movies[-1]
# 'Akshay Kumar'

# %%
# vk[-1] not working

# %%
marks
# Out:
# OOP      67
# CA       89
# JP       78
# DBMS     45
# DC      100
# Name: Marks of Student, dtype: int64

# %%
marks[-1] # when index are string negative indexing works
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18232\2370105898.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   marks[-1] # when index are string negative indexing works
# np.int64(100)

# %%
# Slicing
vk[5:16]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# Name: runs, dtype: int64

# %%
vk[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
movies[-5:]
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object

# %%
subs[::2]
# Out:
# 0       48
# 2       40
# 4       44
# 6       33
# 8       44
#       ...
# 356    156
# 358    210
# 360    231
# 362    155
# 364    172
# Name: Subscribers gained, Length: 183, dtype: int64

# %%
# fancy indexing
vk[[1,3,4]]
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# Name: runs, dtype: int64

# %%
# indexing with labels
movies['Hum Tumhare Hain Sanam']
# Out:
# 'Shah Rukh Khan'

# %% [markdown]
# ### Editing Series

# %%
# using indexing
marks['CA'] = 100
marks
# Out:
# OOP      67
# CA      100
# JP       78
# DBMS     45
# DC      100
# Name: Marks of Student, dtype: int64

# %%
marks['DSA']=83

# %%
marks
# Out:
# OOP      67
# CA      100
# JP       78
# DBMS     45
# DC      100
# DSA      83
# Name: Marks of Student, dtype: int64

# %%
# slicing
runs[2:4] = [100,100]
runs
# Out:
# [10, 50, 100, 100, 0]

# %%
# fancy indexing
runs[[0,3,4]] = [0,0,0]
runs
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 2
#       1 # fancy indexing
# ----> 2 runs[[0,3,4]] = [0,0,0]
#       3 runs
#
# TypeError: list indices must be integers or slices, not list

# %%
# using index label
movies['2 States (2014 film)'] = 'Alia Bhatt'
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Copy and Views

# %% [markdown]
# ### Series with Python Functionalities

# %%
# len/type/dir/sorted/max/min
print(len(subs))
print(type(subs))
# print(dir(subs))
# print(sorted(subs))
print(min(subs))
print(max(subs))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# 33
# 396

# %%
# type conversion
list(marks_series)
# Out:
# [67, 89, 100, 80]

# %%
dict(marks_series)
# Out:
# {'OOP': np.int64(67),
#  'CA': np.int64(89),
#  'JP': np.int64(100),
#  'OB': np.int64(80)}

# %%
# membership operator(works on index)

'2 States (2014 film)' in movies
# Out:
# True

# %%
# use .values to search in values
'Alia Bhatt' in movies.values
# Out:
# True

# %%
# looping
# for i in movies.index:
  # print(i)

# %%
# brodcasting
100 - marks
# Out:
# OOP     33
# CA       0
# JP      22
# DBMS    55
# DC       0
# DSA     17
# Name: Marks of Student, dtype: int64

# %%
# relatinal operation
vk[vk >= 90]
# Out:
# match_no
# 81      93
# 82      99
# 120    100
# 123    108
# 126    109
# 128    113
# 145     92
# 164    100
# 178     90
# Name: runs, dtype: int64

# %%
# Find no of 50's and 100's scored by kohli
vk[vk >= 50].size
# Out:
# 50

# %%
# find number of ducks
vk[vk == 0].size
# Out:
# 9

# %%
# Count number of day when I had more than 200 subs a day
subs[subs > 200].size
# Out:
# 59

# %%
# find actors who have done more than 20 movies
num_movies = movies.value_counts()
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
subs.plot()
# Out:
# <Axes: >

# %%
marks.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind = 'bar')
# Out:
# <Axes: xlabel='lead'>

# %%
movies.value_counts().head(20).plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
# astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
# astype
import sys
sys.getsizeof(vk)
# Out:
# 11768

# %%
sys.getsizeof(vk.astype('int16'))
# Out:
# 10478

# %%
# between
vk[vk.between(51,99)].size
# Out:
# 43

# %%
# clip
subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# drop_duplicates
temp = pd.Series([1,1,2,2,3,3])
temp.drop_duplicates(keep='last')
# Out:
# 1    1
# 3    2
# 5    3
# dtype: int64

# %%
movies.drop_duplicates()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Sssshhh...                              Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                  Tanuja
# Right Here Right Now (film)                        Ankit
# Talaash: The Hunt Begins...                Rakhee Gulzar
# The Pink Mirror                          Edwin Fernandes
# Name: lead, Length: 566, dtype: object

# %%
# Duplicated
temp.duplicated().sum()
# Out:
# np.int64(3)

# %%
vk.duplicated().sum()
# Out:
# np.int64(137)

# %%
# isnull
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.count()
# Out:
# np.int64(7)

# %%
temp.size
# Out:
# 10

# %%
temp.isnull().sum()
# Out:
# np.int64(3)

# %%
# dropna
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
# fillna
temp.fillna(temp.mean())
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
# isin
vk[(vk == 49) | (vk == 99)]
vk[vk.isin([49,99])]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
# apply
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: object

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.apply(lambda x:'Good Day' if x>subs.mean() else "It's okay")
# Out:
# 0      It's okay
# 1      It's okay
# 2      It's okay
# 3      It's okay
# 4      It's okay
#          ...
# 360     Good Day
# 361     Good Day
# 362     Good Day
# 363     Good Day
# 364     Good Day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
# copy

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
new = vk.head() # it gives view of data and if you make some changes in the head or tail it will affect in original
new[1] = 100
new
# Out:
# match_no
# 1    100
# 2     23
# 3     13
# 4     12
# 5      1
# Name: runs, dtype: int64

# %%
vk
# Out:
# match_no
# 1      100
# 2       23
# 3       13
# 4       12
# 5        1
#       ...
# 211      0
# 212     20
# 213     73
# 214     25
# 215      7
# Name: runs, Length: 215, dtype: int64

# %%
vk[1] = 1

# %%
new = vk.head().copy()
new
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
new[1] = 100

# %%
vk.head()
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64
