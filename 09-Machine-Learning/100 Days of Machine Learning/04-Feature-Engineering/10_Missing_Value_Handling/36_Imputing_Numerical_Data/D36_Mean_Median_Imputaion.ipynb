# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('DataSets/D36/titanic_toy.csv')

# %%
df.head()
# Out:
#     Age     Fare  Family  Survived
# 0  22.0   7.2500       1         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       0         1
# 3  35.0  53.1000       1         1
# 4  35.0   8.0500       0         0

# %%
df.isnull().mean()
# Out:
# Age         0.198653
# Fare        0.050505
# Family      0.000000
# Survived    0.000000
# dtype: float64

# %%
X = df.drop(columns = ['Survived']) 
y = df['Survived']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 40)

# %%
X_train.shape , X_test.shape
# Out:
# ((712, 3), (179, 3))

# %%
mean_age = X_train['Age'].mean()
median_age = X_train['Age'].median()

mean_fare = X_train['Fare'].mean()
median_fare = X_train['Fare'].median()

# %%
X_train['Age_median'] = X_train['Age'].fillna(median_age)
X_train['Age_mean'] = X_train['Age'].fillna(mean_age)

X_train['Fare_median'] = X_train['Fare'].fillna(median_fare)
X_train['Fare_mean'] = X_train['Fare'].fillna(mean_fare)

# %%
X_train.sample(5)
# Out:
#       Age     Fare  Family  Age_median  Age_mean  Fare_median  Fare_mean
# 394  24.0  16.7000       2        24.0      24.0      16.7000    16.7000
# 467  56.0  26.5500       0        56.0      56.0      26.5500    26.5500
# 886  27.0  13.0000       0        27.0      27.0      13.0000    13.0000
# 308  30.0  24.0000       1        30.0      30.0      24.0000    24.0000
# 52   49.0  76.7292       1        49.0      49.0      76.7292    76.7292

# %%
print('Original Age variable variance: ', X_train['Age'].var())
print('Age Variance after median imputation: ', X_train['Age_median'].var())
print('Age Variance after mean imputation: ', X_train['Age_mean'].var())

print('Original Fare variable variance: ', X_train['Fare'].var())
print('Fare Variance after median imputation: ', X_train['Fare_median'].var())
print('Fare Variance after mean imputation: ', X_train['Fare_mean'].var())
# Out:
# Original Age variable variance:  209.8419456815438
# Age Variance after median imputation:  169.28551767707359
# Age Variance after mean imputation:  168.81799286897763
# Original Fare variable variance:  2435.9041434806427
# Fare Variance after median imputation:  2332.861077213293
# Fare Variance after mean imputation:  2319.4192758599083

# %%
fig = plt.figure(figsize = (6,5))
ax = fig.add_subplot(111)

# original variable distribution
X_train['Age'].plot(kind='kde', ax=ax)

# variable imputed with the median
X_train['Age_median'].plot(kind='kde', ax=ax, color='red')

# variable imputed with the mean
X_train['Age_mean'].plot(kind='kde', ax=ax, color='green')

# add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
X_train['Fare'].plot(kind='kde', ax=ax)

# variable imputed with the median
X_train['Fare_median'].plot(kind='kde', ax=ax, color='red')

# variable imputed with the mean
X_train['Fare_mean'].plot(kind='kde', ax=ax, color='green')

# add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
X_train.cov()
# Out:
#                     Age         Fare     Family  Age_median    Age_mean  \
# Age          209.841946    52.895778  -7.065278  209.841946  209.841946
# Fare          52.895778  2435.904143  17.682303   45.465560   42.245408
# Family        -7.065278    17.682303   2.659285   -5.647017   -5.684021
# Age_median   209.841946    45.465560  -5.647017  169.285518  168.817993
# Age_mean     209.841946    42.245408  -5.684021  168.817993  168.817993
# Fare_median   49.105591  2435.904143  16.700776   42.461775   39.505483
# Fare_mean     50.000247  2435.904143  16.836736   43.291398   40.225234
#
#              Fare_median    Fare_mean
# Age            49.105591    50.000247
# Fare         2435.904143  2435.904143
# Family         16.700776    16.836736
# Age_median     42.461775    43.291398
# Age_mean       39.505483    40.225234
# Fare_median  2332.861077  2319.419276
# Fare_mean    2319.419276  2319.419276

# %%
X_train.corr()
# Out:
#                   Age      Fare    Family  Age_median  Age_mean  Fare_median  \
# Age          1.000000  0.069328 -0.328162    1.000000  1.000000     0.066012
# Fare         0.069328  1.000000  0.217730    0.070838  0.065907     1.000000
# Family      -0.328162  0.217730  1.000000   -0.266150 -0.268265     0.212036
# Age_median   1.000000  0.070838 -0.266150    1.000000  0.998618     0.067568
# Age_mean     1.000000  0.065907 -0.268265    0.998618  1.000000     0.062951
# Fare_median  0.066012  1.000000  0.212036    0.067568  0.062951     1.000000
# Fare_mean    0.067453  1.000000  0.214381    0.069088  0.064284     0.997115
#
#              Fare_mean
# Age           0.067453
# Fare          1.000000
# Family        0.214381
# Age_median    0.069088
# Age_mean      0.064284
# Fare_median   0.997115
# Fare_mean     1.000000

# %%
X_train[['Age', 'Age_median', 'Age_mean']].boxplot()
# Out:
# <Axes: >

# %%
X_train[['Fare', 'Fare_median', 'Fare_mean']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# # Using Sklearn

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
imputer1 = SimpleImputer(strategy='median')
imputer2 = SimpleImputer(strategy='mean')

# %%
trf = ColumnTransformer([
    ('imputer1',imputer1,['Age']),
    ('imputer2',imputer2,['Fare'])
],remainder='passthrough')

# %%
trf.fit(X_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('imputer1', SimpleImputer(strategy='median'),
#                                  ['Age']),
#                                 ('imputer2', SimpleImputer(), ['Fare'])])

# %%
trf.named_transformers_['imputer1'].statistics_
# Out:
# array([28.75])

# %%
trf.named_transformers_['imputer2'].statistics_
# Out:
# array([32.61759689])

# %%
X_train = trf.transform(X_train)
X_test = trf.transform(X_test)

# %%
X_train
# Out:
# array([[ 40.    ,  27.7208,   0.    ],
#        [  4.    ,  16.7   ,   2.    ],
#        [ 47.    ,   9.    ,   0.    ],
#        ...,
#        [ 71.    ,  49.5042,   0.    ],
#        [ 28.75  , 221.7792,   0.    ],
#        [ 28.75  ,  25.925 ,   0.    ]], shape=(712, 3))
