# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('DataSets/D50/placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
X = df.iloc[:,0].values
y = df.iloc[:,1].values

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 2)

# %%
X_train.shape , X_test.shape
# Out:
# ((160,), (40,))

# %% [markdown]
# <img src = 'https://towardsdatascience.com/wp-content/uploads/2021/10/1lfXkSJgB0tkBdGqHW6NHPg.png'>

# %%
class SimpleLR():
    def __init__(self):
        self.m = None
        self.b = None

    def fit(self,X_train,y_train):
        num = 0
        den = 0

        for i in range(X_train.shape[0]):
            num = num + ((X_train[i] - X_train.mean())*((y_train[i] - y_train.mean())))
            den = den + ((X_train[i] - X_train.mean())*(X_train[i] - X_train.mean()))
        self.m = num/den
        self.b = y_train.mean() - self.m*X_train.mean()
        return self.m , self.b

    def predict(self,X_test):
        return X_test*self.m + self.b

# %%
lr = SimpleLR()

# %%
lr.fit(X_train,y_train)
# Out:
# (np.float64(0.5579519734250721), np.float64(-0.8961119222429152))

# %%
lr.predict(X_test[0])
# Out:
# np.float64(3.891116009744203)
