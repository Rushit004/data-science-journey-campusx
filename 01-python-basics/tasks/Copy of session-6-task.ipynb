# %% [markdown]
# ### **`Problem-1:`** Write a Python function that takes a list and returns a new list with unique elements of the first list.
#
# **Exercise 1:**
#
# Input:
#
# ```bash
# [1,2,3,3,3,3,4,5]
# ```
#
# Output:
#
# ```bash
# [1, 2, 3, 4, 5]
# ```

# %%
def unique_list(l):
  s = set(l)
  return list(s)

l = [1,2,3,3,3,3,4,5]
print(unique_list(l))
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### **`Problem-2:`** Write a Python function that accepts a hyphen-separated sequence of words as parameter and returns the words in a hyphen-separated sequence after sorting them alphabetically.
#
# **Example 1:**
#
# Input:
# ```bash
# green-red-yellow-black-white
# ```
#
# Output:
# ```bash
# black-green-red-white-yellow
# ```

# %%
# Write code here
def sorted_str(s):

  l = list(s.split('-'))
  x = sorted(l)
  out = "-".join(x)
  return out



s = "green-red-yellow-black-white"
print(sorted_str(s))
# Out:
# black-green-red-white-yellow

# %% [markdown]
# ### **`Problem 3:`** Write a Python function that accepts a string and calculate the number of upper case letters and lower case letters.
#
# ```
# Sample String : 'CampusX is an Online Mentorship Program fOr EnginEering studentS.'
# Expected Output :
# No. of Upper case characters :  9
# No. of Lower case Characters :  47
# ```

# %%
# Write code here
def calculate(s):
  cnt = 0
  cnt1 = 0
  for i in s:
    x = str(i)
    if x.islower():
      cnt+=1
    elif x.isupper():
      cnt1+=1
  print('No. of Upper case characters :',cnt1)
  print('No. of Lower case characters :',cnt)
s = 'CampusX is an Online Mentorship Program fOr EnginEering studentS.'
calculate(s)
# Out:
# No. of Upper case characters : 9
# No. of Lower case characters : 47

# %% [markdown]
# ### **`Problem 4:`** Write a Python program to print the even numbers from a given list.
# ```
# Sample List : [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Expected Result : [2, 4, 6, 8]
# ```

# %%
# Write code here

def count_even_no(l):
  l1 = []
  for i in l:
    if i%2==0:
      l1.append(i)
  return l1


l =  [1, 2, 3, 4, 5, 6, 7, 8, 9]

print(count_even_no(l))
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# ### **`Problem 5:`** Write a Python function to check whether a number is perfect or not.
#
# A Perfect number is a number that is half the sum of all of its positive divisors (including itself).
#
# Example :
#
# ```
# The first perfect number is 6, because 1, 2, and 3 are its proper positive divisors, and 1 + 2 + 3 = 6.
# Equivalently, the number 6 is equal to half the sum of all its positive divisors: ( 1 + 2 + 3 + 6 ) / 2 = 6.
#
# The next perfect number is 28 = 1 + 2 + 4 + 7 + 14. This is followed by the perfect numbers 496 and 8128.
# ```

# %%
# Write code here
def perfect_no(x):
  sum = 0
  for i in range(1,x+1):
    if x%i == 0:
      sum+=i
  if sum/2 == x:
    print('Number is Perfect.')
  else:
    print('Number is not Perfect.')

n = int(input('Enter number:'))
perfect_no(n)
# Out:
# Enter number:4
# Number is not Perfect.

# %% [markdown]
# ### **`Problem-6:`** Write a Python function to concatenate any no of dictionaries to create a new one.
#
# ```
# Sample Dictionary :
# dic1={1:10, 2:20}
# dic2={3:30, 4:40}
# dic3={5:50,6:60}
# Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
# ```

# %%
# hint needed
# Write code here

def concatenat(**kwargs):
  dic = {}
  for (key,value) in kwargs.items():
    dic[key] = value

  return dic


n = int(input('Enter total no. of dictionary:'))
dict2 = {}
for i in range(0,n):
  k = input('Enter key')
  val = input('Enter value ')
  result = concatenat(**{k :val})
  dict2.update(result)
print(dict2)
# Out:
# Enter total no. of dictionary:2
# Enter keysg
# Enter value 4
# Enter keygf
# Enter value 5
# {'sg': '4', 'gf': '5'}

# %% [markdown]
# `Problem-7` Write a python function that accepts a string as input and returns the word with most occurence.
#
# ```
# Input:
# hello how are you i am fine thank you
# ```
#
# ```
# Output
# you -> 2
# ```

# %%
# Write code here
def frequency_count(s):
  max_cnt = 0
  l = s.split()
  for i in l:
    x = l.count(i)
  max_cnt = max(max_cnt,x)
  word = i
  print(word,max_cnt,sep=' -> ')



s = 'hello how are you i am fine thank you by by by'
frequency_count(s)
# Out:
# by -> 3

# %% [markdown]
# `Problem-8` Write a python function that receives a list of integers and prints out a histogram of bin size 10
#
# ```
# Input:
# [13,42,15,37,22,39,41,50]
# ```
#
# ```
# Output:
# {11-20:2,21-30:1,31-40:2,41-50:3}
# ```

# %%
# Write code here
def plot(l):
  min_s = (min(l)//10)*10
  max_s = (max(l)//10)*10

  dict1 = {}

  for i in range(min_s,max_s,10):
    cnt = 0

    for j in range(i+1,i+11):

      if j in l:
        cnt+=1

    dict1[str(i+1) +'-'+str(i+10)] =cnt
  return dict1

l = [13,42,15,37,22,39,41,50]
print(plot(l))
# Out:
# {'11-20': 2, '21-30': 1, '31-40': 2, '41-50': 3}

# %% [markdown]
# `Problem-9` Write a python function that accepts a list of 2D co-ordinates and a query point, and then finds the the co-ordinate which is closest in terms of distance from the query point.
#
# ```
# List of Coordinates
# [(1,1),(2,2),(3,3),(4,4)]
# Query Point
# (0,0)
# ```
#
# ```
# Output
# Nearest to (0,0) is (1,1)
# ```

# %%
# Write code here
def closet_cordinate(l,q):
  x0 = q[0]
  y0 = q[1]
  min_dist = 1000000000
  for i in l:
    x = i[0]
    y = i[1]

    dist = ((x0 - x)**2 + (y0 - y)**2)**0.5

    if min_dist>dist:
      cor = i

  return i

l = [(1,1),(2,2),(3,3),(4,4),(0,1)]
q = (0,0)

print(closet_cordinate(l,q))
# Out:
# (0, 1)

# %% [markdown]
# `Problem-10`:Write a python program that receives a list of strings and performs bag of word operation on those strings
#
# https://en.wikipedia.org/wiki/Bag-of-words_model

# %%
# Write code here
def Bow(l):
  list2 = []
  for i in l:
    list1 = list(i.split())
    dict1 = {}

    for j in list1:
      dict1[j] = list1.count(j)
    list2.append(dict1)
  return list2






l = ['John likes to watch movies. Mary likes movies too.','Mary also likes to watch football games.']
print(Bow(l))
# Out:
# [{'John': 1, 'likes': 2, 'to': 1, 'watch': 1, 'movies.': 1, 'Mary': 1, 'movies': 1, 'too.': 1}, {'Mary': 1, 'also': 1, 'likes': 1, 'to': 1, 'watch': 1, 'football': 1, 'games.': 1}]

# %% [markdown]
# ###`Problem 11:` Write a Python program to add three given lists using Python map and lambda.

# %%
# Write code here
l1 = [1,2,3,4]
l2 = [5,6,7,8]
l3 = [9,10,11,12]

list(map(lambda x,y,z : x+y+z ,l1,l2,l3))
# Out:
# [15, 18, 21, 24]

# %% [markdown]
# ###`Problem-12:`Write a Python program to create a list containing the power of said number in bases raised to the corresponding number in the index using Python map.
# `Input:`
# ```
# list1 = [1,2,3,4,5,6]
# ```
# `Output:`
# ```
# [1,2,9,64,625,-]
# ```

# %%
# Write code here
list1 = [1,2,3,4,5,6]

list(map(lambda x : x**list1.index(x),list1))
# Out:
# [1, 2, 9, 64, 625, 7776]

# %% [markdown]
# ###`Problem-13` Using filter() and list() functions and .lower() method filter all the vowels in a given string.

# %%
# Write code here
s = 'abcdefghijklmnopqrstuvwxyaAz'
s = s.lower()
list(filter(lambda x:x in ('a','e','i','o','u'),s))
# Out:
# ['a', 'e', 'i', 'o', 'u', 'a', 'a']

# %% [markdown]
# `Problem-14`: Use reduce to convert a 2D list to 1D

# %%
# Write code here
import functools
l1 = [[1,2,3,],[4,5,6]]
functools.reduce(lambda x,y : x+y, l1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# `Problem 15`- A dictionary contains following information about 5 employees:
# - First name
# - Last name
# - Age
# - Grade(Skilled,Semi-skilled,Highly skilled)<br>
# Write a program using map/filter/reduce to a list of employees(first name + last name) who are highly skilled

# %%
# not able to do
# Write code here
employees = [
    {
        'fname':'Nitish',
        'lname':'Singh',
        'age' : 33,
        'grade':'skilled'
    },
    {
        'fname':'Ankit',
        'lname':'Verma',
        'age' : 34,
        'grade':'semi-skilled'
    },
    {
        'fname':'Neha',
        'lname':'Singh',
        'age' : 35,
        'grade':'highly-skilled'
    },
    {
        'fname':'Anurag',
        'lname':'Kumar',
        'age' : 30,
        'grade':'skilled'
    },
    {
        'fname':'Abhinav',
        'lname':'Sharma',
        'age' : 37,
        'grade':'highly-skilled'
    }

]

# %%
list(map(lambda x:x['fname'] + ' ' + x['lname'],list(filter(lambda x:True if x['grade'] == 'highly-skilled' else False,employees))))
# Out:
# ['Neha Singh', 'Abhinav Sharma']

# %%
list(map(lambda x:x['fname'] + ' '+ x['lname'],list(filter(lambda x: True if x['grade']=='highly-skilled' else False,employees))))
# Out:
# ['Neha Singh', 'Abhinav Sharma']
