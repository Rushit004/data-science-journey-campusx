# %% [markdown]
# ### `Problem-1:` Class inheritence
#
# Create a **Bus** child class that inherits from the Vehicle class. The default fare charge of any vehicle is seating capacity * 100. If Vehicle is Bus instance, we need to add an extra 10% on full fare as a maintenance charge. So total fare for bus instance will become the final amount = total fare + 10% of the total fare.
#
# Note: The bus seating capacity is 50. so the final fare amount should be 5500. You need to override the fare() method of a Vehicle class in Bus class.

# %%
# Write code here
class Vehicle:
  def __init__(self):
    pass
  def Fare(self,capacity):
    return capacity*100


class Bus(Vehicle):
  def __init__(self):
    pass

  def Fare(self,capacity):
    return super().Fare(capacity)*1.1


Vehicle1 = Vehicle()
print(Vehicle1.Fare(50))

bus1 = Bus()
print(bus1.Fare(50))
# Out:
# 5000
# 5500.0

# %% [markdown]
# ### `Problem-2:` Class Inheritence
#
# Create a Bus class that inherits from the Vehicle class. Give the capacity argument of *Bus.seating_capacity()* a default value of 50.
#
# Use the following code for your parent Vehicle class.

# %%
# Write code here
class Vehicle:
  def __init__(self):
    pass
  def Fare(self,capacity):
    return capacity*100


class Bus(Vehicle):
  def __init__(self):
    pass

  def Fare(self,capacity=50):
    return super().Fare(capacity)*1.1


Vehicle1 = Vehicle()
print(Vehicle1.Fare(50))

bus1 = Bus()
print(bus1.Fare())
# Out:
# 5000
# 5500.0

# %% [markdown]
# ### `Problem-3:` Write a program that has a class Point. Define another class Location which has two objects (Location & Destination) of class Point. Also define a function in Location that prints the reflection of Destination on the x axis.

# %%
class Points:
  def __init__(self,x,y):

    self.x_cod = x
    self.y_cod = y



class Location(Points):
  def __init__(self,x,y):
    super().__init__(x,y)
  def display(self):
    print('Points : <{},{}>'.format(self.x_cod,self.y_cod))


  def Reflaction_x(self):
    reflected_y = -1*self.y_cod
    reflected_x = self.x_cod
    print('Reflacted cordinates of <{},{}>  : <{},{}> '.format(self.x_cod,self.y_cod,reflected_x,reflected_y))


point1 = Points(4,5)

loc1 = Location(1,2)
des1 = Location(-1,-2)
loc1.display()
des1.display()
loc1.Reflaction_x()
des1.Reflaction_x()
# Out:
# Points : <1,2>
# Points : <-1,-2>
# Reflacted cordinates of <1,2>  : <1,-2>
# Reflacted cordinates of <-1,-2>  : <-1,2>

# %% [markdown]
# ### `Problem-4:` Write a program that has an abstract class Polygon. Derive two classes Rectangle and Triamgle from Polygon and write methods to get the details of their dimensions and hence calculate the area.

# %%
from abc import abstractclassmethod

class Polygon:
  @abstractclassmethod
  def get_details(self,x,y):
    pass


class Rectangle(Polygon):
  def __init__(self,l,b):
    self.length = l
    self.bredth = b
  def area(self):
    print('Area = ',self.bredth*self.length)




class Triangle(Polygon):
  def __init__(self,b,h):
    self.base = b
    self.height = h
  def area(self):
    print('Area = ',self.base*self.height*0.5)

rec1 = Rectangle(4,5)
rec1.area()
tri = Triangle(5,4)
tri.area()
# Out:
# Area =  20
# Area =  10.0

# %% [markdown]
# ### `Problem-5:` Write a program with class Bill. The users have the option to pay the bill either by cheque or by cash. Use the inheritance to model this situation.

# %%
class Bill:
    def __init__(self, amt):
        self.amount = amt

    def display(self):
        print("Amount to pay =", self.amount)


class Check(Bill):
    def __init__(self, amt):
        print("Payment with Check")
        super().__init__(amt)


class Cash(Bill):
    def __init__(self, amt):
        print("Payment with Cash")
        super().__init__(amt)



amt = int(input("Enter bill amount: "))

choice = input("Pay by (check/cash): ").lower()

if choice == "check":
    payment = Check(amt)
elif choice == "cash":
    payment = Cash(amt)
else:
    print("Invalid payment method")
    exit()

payment.display()
# Out:
# Enter bill amount: 5000
# Pay by (check/cash): check
# Payment with Check
# Amount to pay = 5000

# %% [markdown]
# ###`Q-6:` FlexibleDict
# As of now we are accessing values from dictionary with exact keys. Now we want to amend accessing values functionality. if a dict have key `1` (int) the even if we try to access values by giving `'1'` (1 as str) as key, we should get the same result and vice versa.
#
# Write a class `FlexibleDict` upon builtin `dict` class with above required functionality.
#
# Hint- `dict[key] => dict.__getitem__(key)`

# %% [markdown]
# Ex.
# ```
# fd = FlexibleDict()
# fd['a'] = 100
# print(fd['a']) # Like regular dict
#
# fd[5] = 500
# print(fd[5]) # Like regular dict
#
# fd[1] = 100
# print(fd['1']) # actual Key is int but still trying to access through str key.
# fd['1'] = 100
# print(fd[1])
#
# ```
# `Output:`
# ```
# 100
# 500
# 100
# 100
#
# ```

# %%
# copy
class FlexibleDict(dict):

    def __getitem__(self, key):
        # Try normal access first
        if key in self:
            return super().__getitem__(key)

        # If key is string digit → try integer version
        if isinstance(key, str) and key.isdigit():
            int_key = int(key)
            if int_key in self:
                return super().__getitem__(int_key)

        # If key is integer → try string version
        if isinstance(key, int):
            str_key = str(key)
            if str_key in self:
                return super().__getitem__(str_key)

        # If nothing found → raise error
        raise KeyError(key)

# %%
d = FlexibleDict({1: "One", "2": "Two", 3: "Three"})

print(d[1])     # One
print(d['1'])   # One

print(d[2])     # Two
print(d['2'])   # Two

print(d[3])     # Three
print(d['3'])   # Three
# Out:
# One
# One
# Two
# Two
# Three
# Three
