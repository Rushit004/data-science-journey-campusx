# %% [markdown]
# 1. Print

# %%
print('Hello World')
# Out:
# Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(4)
# Out:
# 4

# %%
print(True)
# Out:
# True

# %%
print(82.11)
# Out:
# 82.11

# %%
print('hii',123,1.22,True)
# Out:
# hii 123 1.22 True

# %%
print('Hii','Rushit',1.2,False,sep ='/')
# Out:
# Hii/Rushit/1.2/False

# %%
print('Hello',end='_')
print('Rushit',end = ';')
# Out:
# Hello_Rushit;

# %% [markdown]
# 2. Data Types

# %%
#integer
#1*(10^308)
print(1e308)
print(1e309)
# Out:
# 1e+308
# inf

# %%
# Float
print(10.23)
print(1e308)
print(1e309)
# Out:
# 10.23
# 1e+308
# inf

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# String
print('Rushit')
# Out:
# Rushit

# %%
# Coplex number
print(1+5j)
# Out:
# (1+5j)

# %%
# List
print([1,2.2,'Rushit',True])
# Out:
# [1, 2.2, 'Rushit', True]

# %%
# Tuple
print((1,'RT',2.2,False))
# Out:
# (1, 'RT', 2.2, False)

# %%
# Sets
print({1,1,2,2,'RT','Rt'})
# Out:
# {'Rt', 1, 2, 'RT'}

# %%
# Dictionary
print({'name':'Rushit','age':18,50:'Weight'})
# Out:
# {'name': 'Rushit', 'age': 18, 50: 'Weight'}

# %%
print(type(4.5))
print(type('4.5'))
# Out:
# <class 'float'>
# <class 'str'>

# %% [markdown]
# 3. Variables

# %%
name = 'Rushit'
age = 18
print(name , age)
# Out:
# Rushit 18

# %%
# Dynamic Typing(You do not tell Datatype of variable)
a = 5
# Static Typing(You define the type of variable)

#int b = 10(not allowed in python)
# Dynamic Binding(one variable can be used by several datatypes )
a = 20
print(a)
a = 'Rushit'
print(a)
# Out:
# 20
# Rushit

# %%
a,b,c = 1,20,20.1
print(a,b,c,sep =' < ')

a=b=c=5
print(a,b,c,sep = ' = ')
# Out:
# 1 < 20 < 20.1
# 5 = 5 = 5

# %% [markdown]
# 4. Comments

# %%
# this is comment
# no multiline comments allowed.

# %% [markdown]
# 5. Keywords and identifiers

# %%
# keywords : 39 (35 Standerd + 4 Soft)

# Category               	Keywords

# Boolean & Null           :True, False, None
# Control Flow	           :if, elif, else, match, case
# Loops	                   :for, while, break, continue, pass
# Logic & Operators	       :and, or, not, in, is
# Functions & Classes	   :def, return, lambda, yield, class
# Exceptions	           :try, except, finally, raise, assert, except**
# Modules	               :import, from, as
# Scope	                   :global, nonlocal, del
# Async	                   :async, await
# Context Management	   :with, as

# %%
# Identifiers

# Alphanumeric values allowed.
# You can't start with digits.
# you can use Special character only '_'.
# identifiers can't be keywords.

# %% [markdown]
# 6. User input

# %%
input()
# Out:
#  HII
# 'HII'

# %%
input('Enter name:')
# Out:
# Enter name: Rushit
# 'Rushit'

# %%
a = input('Enter 1st number:')
b = int(input('Enter 2nd number:'))
print(type(a),type(b))
print('a =',a,'b =',b)
print('Sum =',int(a)+b)
print(type(a))
# Out:
# Enter 1st number: 40
# Enter 2nd number: 60
# <class 'str'> <class 'int'>
# a = 40 b = 60
# Sum = 100
# <class 'str'>

# %% [markdown]
# 7. Type conversion

# %%
# implicit
print(5 + 3.2)
# Out:
# 8.2

# %%
# Explicit
a =int('5')
print(a)
print(type(a))

b = 4.5
print(str(4.5))
print(type(b))

c = str(1.23)
print(c)
print(type(c))
# Out:
# 5
# <class 'int'>
# 4.5
# <class 'float'>
# 1.23
# <class 'str'>

# %% [markdown]
# 8. Literals(row values you store in variables)

# %%
# Binary
a = 0b1010 # 0b1010 is literal
print(type(a))
print(a)

# Octal
b = 0o7
print(type(b))
print(b)

# hexadecimal

c = 0xF
print(type(c))
print(c)



# Floats

a = 10.2
print(a)

b = 1.5e2 # 1.5 * 10 ^2
print(b)

c = 1.5e-2 # 1.5 * 10 ^-2
print(c)



# complex
com  = 15 + 10j
print(com.real,com.imag)




# Strings
s0 = 'Rushit'
print(s)
s0= "Rushit"
print(s0)
s0= '''Rushit'''
print(s0)

unicode = "\U0001F642"
print(unicode)

raw_str = "raw \nstring"
print(raw_str)

# boolean
a = True + 2
b = False + 2
print('a:',a,'b:',b)

# none
a = None
print(a)
# Out:
# <class 'int'>
# 10
# <class 'int'>
# 7
# <class 'int'>
# 15
# 10.2
# 150.0
# 0.015
# 15.0 10.0
# Rushit
# Rushit
# Rushit
# 🙂
# raw
# string
# a: 3 b: 2
# None
